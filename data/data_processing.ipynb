# %%
from retail_cleaning_pipeline import clean_retail_data

# Clean the data
clean_df = clean_retail_data("raw.xlsx")

# Save to CSV and Excel
clean_df.to_excel("cleaned_retail.xlsx", index=False)

print("✅ Data exported successfully.")
# Out:
# INFO:root:Loading data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from retail_cleaning_pipeline import clean_retail_data
#       3 # Clean the data
# ----> 4 clean_df = clean_retail_data("raw.xlsx")
#       6 # Save to CSV and Excel
#       7 clean_df.to_excel("cleaned_retail.xlsx", index=False)
#
# File c:\Users\lmcr-\Downloads\DSI\final_project\ml4-online-retail\data\retail_cleaning_pipeline.py:85, in clean_retail_data(path)
#      83 def clean_retail_data(path: str) -> pd.DataFrame:
#      84     logging.info("Loading data...")
# ---> 85     df = load_data(path)
#      86     logging.info("Adding date columns...")
#      87     df = add_date_columns(df)
#
# File c:\Users\lmcr-\Downloads\DSI\final_project\ml4-online-retail\data\retail_cleaning_pipeline.py:6, in load_data(path)
#       5 def load_data(path: str) -> pd.DataFrame:
# ...
